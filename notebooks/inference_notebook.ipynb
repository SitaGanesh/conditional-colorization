# %%
import sys, os

# Make sure we're in the project root  
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')
    
sys.path.append(os.path.abspath("."))
import torch
from src.inference import run_inference
print("Imports successful!")
# Out:
# Imports successful!

# %%
# Cell 2: Check if checkpoint exists first, then run inference
import os
device = "cuda" if torch.cuda.is_available() else "cpu"

# Find the most recent checkpoint
checkpoint_dir = "checkpoints"
if os.path.exists(checkpoint_dir):
    checkpoints = [f for f in os.listdir(checkpoint_dir) if f.startswith("ckpt_epoch_") and f.endswith(".pth")]
    if checkpoints:
        # Use the latest checkpoint
        latest_ckpt = sorted(checkpoints)[-1]
        ckpt_path = os.path.join(checkpoint_dir, latest_ckpt)
        print(f"Using checkpoint: {ckpt_path}")
        
        # Find an image in data/val
        val_images = [f for f in os.listdir("data/val") if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        if val_images:
            img_path = os.path.join("data/val", val_images[0])
            print(f"Using image: {img_path}")
            run_inference(img_path, ckpt_path, color_hex="#00aaff", mask_path=None, out_path="notebooks/1014.jpg", device=device)
        else:
            print("No images found in data/val/")
    else:
        print("No checkpoints found! Train the model first.")
else:
    print("Checkpoints directory doesn't exist! Train the model first.")
# Out:
# Using checkpoint: checkpoints\ckpt_epoch_1.pth
# Using image: data/val\0.jpg
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 20
#      18     img_path = os.path.join("data/val", val_images[0])
#      19     print(f"Using image: {img_path}")
# ---> 20     run_inference(img_path, ckpt_path, color_hex="#00aaff", mask_path=None, out_path="notebooks/1014.jpg", device=device)
#      21 else:
#      22     print("No images found in data/val/")
#
# File D:\colorization_task3\conditional-colorization-project\src\inference.py:19, in run_inference(img_path, ckpt, color_hex, mask_path, out_path, device)
#      18 def run_inference(img_path, ckpt, color_hex=None, mask_path=None, out_path="out.png", device="cpu"):
# ---> 19     model, size = load_model(ckpt, device=device)
#      20     img = Image.open(img_path).convert("RGB").resize((size, size))
# ...

# %%
# Cell 3
from PIL import Image
display(Image.open("notebooks/1014.jpg"))
